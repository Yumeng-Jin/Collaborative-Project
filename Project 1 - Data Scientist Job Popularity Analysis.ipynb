# %% [markdown]
# ## __Build Database for Data Scientist Job Popularity Analysis__

# %% [markdown]
# Owners: Alexa Aguirre / Bernardo Arambula / Yumi Jin

# %%
# Import packages
import os
import re
import time
import random
import warnings
import requests
import mysql.connector
from bs4 import BeautifulSoup

# %% [markdown]
# ### __Part 1 - Scraping and Saving HTML Content__
# Since LinkedIn has __strict antiscraping policies__ and __a stable layout__, we prefer to use Beautiful Soup and Requests instead of Selenium to extract the data we need.
#
# First we need to saved the job listings url to a list for further usage.

# %%
# Initialize session and set headers
session = requests.Session()
headers = {
    'User-agent': 'Mozilla/5.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive'
}

# Set base URL and query parameters
base_url = "https://www.linkedin.com/jobs/search/"
query_params = {
    'distance': '25',
    'geoId': '103644278',
    'keywords': 'data scientist',
    'origin': 'JOBS_HOME_KEYWORD_HISTORY',
    'refresh': 'true',
    'start': 0
}

# %%
# Create a empty list to store the jobs' url
links = []

for page in range(1, 120): 
    # Update the start value in the query parameter
    query_params['start'] = (page - 1) * 25
    try:
        response = session.get(base_url, params=query_params, headers=headers)
        # Random sleep to avoid being detected as a bot
        time.sleep(random.uniform(10, 16)) 
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find the list containing job results
        jobs_list = soup.find('ul', class_='jobs-search__results-list')
        if jobs_list:
            # Extract all job cards from the list
            job_cards = jobs_list.find_all('li', recursive=False)  # 'recursive=False' ensures it only looks at direct children
            for card in job_cards:
                link_tag = card.find('a', class_='base-card__full-link')
                if link_tag and link_tag.get('href'):
                    links.append(link_tag.get('href'))
                    
    except requests.exceptions.RequestException as e:
        print(e)
    except Exception as e:
        print(f"An error occurred: {e}")     
# print(links)
# Out:
# HTTPSConnectionPool(host='www.linkedin.com', port=443): Max retries exceeded with url: /jobs/search/?distance=25&geoId=103644278&keywords=data+scientist&origin=JOBS_HOME_KEYWORD_HISTORY&refresh=true&start=300 (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# ['https://www.linkedin.com/jobs/view/data-scientist-at-rue-gilt-groupe-3858021032?position=1&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=m4vBNl%2BXpG1foOsJgbn%2BIw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-rent-the-runway-3857251816?position=2&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=VwQd0UGMwotxNUpmxvSYyg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-rue-gilt-groupe-3863111235?position=3&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=9bv%2BGHypCs15T5WBFHlVxw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-zest-ai-3858182172?position=4&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=0BW8vQ77EsmbxZhjLczGsQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/junior-data-scientist-at-clearml-3855831463?position=5&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=21H2qz61pY18lOY9bHEE4A%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-ii-at-oscar-health-3862929712?position=6&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=QAvK0UjuMTs13sN9ObI4bg%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-entry-level-at-hiremefast-llc-3862311554?position=7&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=UZ0WOmAsS5yVmtWOflyqcQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-mysten-labs-3860722872?position=8&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=hgLt%2BB9a4aEN2bCsE17A7w%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-ascendion-3859071688?position=9&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=qg3BVM%2Bd5traitutP001LQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/junior-data-scientist-at-team-remotely-inc-3862309759?position=10&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=ccfywMn2nhxPuH6jbnBrBQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-ii-at-oscar-health-3843341563?position=11&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=IDYKddFmfzFh2GmTKH5PSQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-ayesa-3853999823?position=12&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=33NwJNX3V%2FNVfpB8ip8Diw%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/jr-r-d-data-scientist-at-eos-energy-enterprises-inc-3860971043?position=13&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=IzMR%2F%2BUw7762oKa9%2FRIxag%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-life-sciences-at-zifo-3859043348?position=14&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=jeTiu3dZOR5634JGsG%2FbvQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-product-analytics-at-meta-3831043502?position=15&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=vGNAcqHVVELw%2BVNYHY2FaA%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-microsoft-3852734486?position=16&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=h%2FqnRE0RKM4mGZmfxBZMOQ%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-unreal-staffing-inc-3853582288?position=17&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=vCIO1laPCeJZgmgNzSvQ8w%3D%3D&trk=public_jobs_jserp-result_search-card', 'https://www.linkedin.com/jobs/view/data-scientist-at-brex-technologies-llc-3857518902?position=18&pageNum=0&refId=Q1hjp0FvPXg%2FDcg5CwvnkA%3D%3D&trackingId=XhZVhnuAnk5bGAzte8N ...

# %%
len(links)
# Out:
# 1560

# %% [markdown]
# We scraped __1,560__ data scientist job listings.
# However, many of them are __duplicated__ because a single job may be listed multiple times. And also because of the __antiscraping policies__, it's hard to parse all of them, so the actual number may __decrease__ once we parse and individually save them to HTML files.
#
# To avoid being blocked, we initially divide the list and then request and save each listing individually.

# %%
# Slice up the links to perform web-scraping to avoid being blocked
links1 = links[0:200]
links2 = links[200:400]
links3 = links[400:600]
links4 = links[600:800]
links5 = links[800:1000]
links6 = links[1000:1200]
links7 = links[1200:1400]
links8 = links[1400:1560]

# %%
for link in links8:
    # Random sleep to avoid being detected as a bot
    time.sleep(random.uniform(5, 8)) 
    
    # Extract the job ID using regular expression
    job_id = re.search(r'jobs/view/.+-([0-9]+)\?', link)
    job_id = job_id.group(1)
    
    # Define the filename using the job ID
    filename = f"{job_id}.html"
    
    # For each of the listing URLs, use `requests` to fetch the listing page
    page = requests.get(link, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')

    # Save each HTML content to a separate file on disk
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(soup.prettify())
    print(f"Successfully saved {filename}")
# Out:
# Successfully saved 3860178110.html
# Successfully saved 3854663368.html
# Successfully saved 3853735090.html
# Successfully saved 3856411900.html
# Successfully saved 3862979601.html
# Successfully saved 3853535578.html
# Successfully saved 3855850785.html
# Successfully saved 3858005565.html
# Successfully saved 3862707722.html
# Successfully saved 3860177195.html
# Successfully saved 3859408313.html
# Successfully saved 3851331090.html
# Successfully saved 3858583560.html
# Successfully saved 3857211517.html
# Successfully saved 3860582081.html
# Successfully saved 3862940904.html
# Successfully saved 3862312442.html
# Successfully saved 3862308771.html
# Successfully saved 3855866045.html
# Successfully saved 3860723838.html
# Successfully saved 3858976610.html
# Successfully saved 3855858013.html
# Successfully saved 3858176868.html
# Successfully saved 3860581193.html
# Successfully saved 3860726934.html
# Successfully saved 3860174658.html
# Successfully saved 3848276079.html
# Successfully saved 3858224052.html
# Successfully saved 3861696805.html
# Successfully saved 3852719674.html
# Successfully saved 3858975629.html
# Successfully saved 3862333694.html
# Successfully saved 3854754001.html
# Successfully saved 3859341162.html
# Successfully saved 3857262592.html
# Successfully saved 3854362334.html
# Successfully saved 3859093324.html
# Successfully saved 3853058784.html
# Successfully saved 3860733029.html
# Successfully saved 3850727249.html
# Successfully saved 3863111235.html
# Successfully saved 3858021032.html
# Successfully saved 3857251816.html
# Successfully saved 3858182172.html
# Successfully saved 3855831463.html
# Successfully saved 3862929712.html
# Successfully saved 3860722872.html
# Successfully saved 3859071688.html
# Successfully saved 3862311554.html
# Successfully saved 3862309759.html
# Successfully saved 3843341563.html
# Successfully saved 3853999823.html
# Successfully saved 3859043348.html
# Successfully saved 3860971043.html
# Successfully saved 3831043502.html
# Successfully saved 3852734486.html
# Successfully saved 3853582288.html
# Successfully saved 3857518902.html
# Successfully saved 3851773982.html
# Successfully saved 3854076940.html
# Successfully saved 3860178110.html
# Successfully saved 3854663368.html
# Successfully saved 3853735090.html
# Successfully saved 3856411900.html
# Successfully saved 3862979601.html
# Successfully saved 3853535578.html
# Successfully saved 3855850785.html
# Successfully saved 3858005565.html
# Successfully saved 3862707722.html
# Successfully saved 3860177195.html
# Successfully saved 3859408313.html
# Successfully saved 3851331090.html
# Successfully saved 3858583560.html
# Successfully saved 3857211517.html
# Successfully saved 3860582081.html
# Successfully saved 3862940904.html
# Successfully saved 3862312442.html
# Successfully saved 3862308771.html
# Successfully saved 3855866045.html
# Successfully saved 3860723838.html
# Successfully saved 3858976610.html
# Successfully saved 3855858013.html
# Successfully saved 3858176868.html
# Successfully saved 3860581193.html
# Successfully saved 3860726934.html
# Successfully saved 3860174658.html
# Successfully saved 3848276079.html
# Successfully saved 3858224052.html
# Successfully saved 3861696805.html
# Successfully saved 3852719674.html
# Successfully saved 3858975629.html
# Successfully saved 3862333694.html
# Successfully saved 3854754001.html
# Successfully saved 3859341162.html
# Successfully saved 3857262592.html
# Successfully saved 3854362334.html
# Successfully saved 3859093324.html
# Successfully saved 3853058784.html
# Successfully saved 3860733029.html
# Successfully saved 3850727249.html
# Successfully saved 3863111235.html
# Successfully saved 3858021032.html
# Successfully saved 3857251816.html
# Successfully saved 3858182172.html
# Successfully saved 3855831463.html
# Successfully saved 3862929712.html
# Successfully saved 3860722872.html
# Successfully saved 3859071688.html
# Successfully saved 3862311554.html
# Successfully saved 3862309759.html
# Successfully saved 3843341563.html
# Successfully saved 3853999823.html
# Successfully saved 3859043348.html
# Successfully saved 3860971043.html
# Successfully saved 3831043502.html
# Successfully saved 3852734486.html
# Successfully saved 3853582288.html
# Successfully saved 3857518902.html
# Successfully saved 3851773982.html
# Successfully saved 3854076940.html
# Successfully saved 3860178110.html
# Successfully saved 3854663368.html
# Successfully saved 3853735090.html
# Successfully saved 3856411900.html
# Successfully saved 3862979601.html
# Successfully saved 3853535578.html
# Successfully saved 3855850785.html
# Successfully saved 3858005565.html
# Successfully saved 3862707722.html
# Successfully saved 3860177195.html
# Successfully saved 3859408313.html
# Successfully saved 3851331090.html
# Successfully saved 3858583560.html
# Successfully saved 3857211517.html
# Successfully saved 3860582081.html
# Successfully saved 3862940904.html
# Successfully saved 3862312442.html
# Successfully saved 3862308771.html
# Successfully saved 3855866045.html
# Successfully saved 3860723838.html
# Successfully saved 3858976610.html
# Successfully saved 3855858013.html
# Successfully saved 3858176868.html
# Successfully saved 3860581193.html
# Successfully saved 3860726934.html
# Successfully saved 3860174658.html
# Successfully saved 3848276079.html
# Successfully saved 3858224052.html
# Successfully saved 3861696805.html
# Successfully saved 3852719674.html
# Successfully saved 3858975629.html
# Successfully saved 3862333694.html
# Successfully saved 3854754001.html
# Successfully saved 3859341162.html
# Successfully saved 3857262592.html
# Successfully saved 3854362334.html
# Successfully saved 3859093324.html
# Successfully saved 3853058784.html
# Successfully saved 3860733029.html
# Successfully saved 3850727249.html

# %% [markdown]
# ---

# %% [markdown]
# ### __Part 2 - Get the needed information from the HTML files__
# Now, we loop through each HTML files we just saved, and extract the needed information.

# %%
# Set the relative path
directory = '/Users/yumi/ucdavis/Winter Quarter/BAX-422/Final Project/html files/'

# create an empty list to store the job_info for future usage
job_list = []

# Loop through each saved HTML file from the path 
for filename in os.listdir(directory):
    # Check if the file ends with .html
    if filename.endswith(".html"):
        # Construct the full file path using the relative directory
        filepath = os.path.join(directory, filename)
        # Read the file content
        with open(filepath, 'r', encoding='utf-8') as file:
            html_content = file.read()
            # For each HTML file, use `BeautifulSoup` to parse the file content
            soup = BeautifulSoup(html_content, 'html.parser')
            
            job_id = filename.split(".")[0]
            job_title = soup.find('h1', class_='top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title')
            if job_title:
                job_title = job_title.get_text(strip=True)
            company_name = soup.find('a', class_='topcard__org-name-link topcard__flavor--black-link').get_text(strip=True)
            location = soup.find('span', class_='topcard__flavor topcard__flavor--bullet').get_text(strip=True)
            post_date = soup.find('span', class_='posted-time-ago__text').get_text(strip=True)
            applicant_num = soup.find('span', class_='num-applicants__caption')
            if applicant_num:
                applicant_num = applicant_num.get_text(strip=True)
            else:
                applicant_num = soup.find('figcaption', class_='num-applicants__caption')
                if applicant_num:
                    applicant_num = applicant_num.get_text(strip=True)
                else:
                    applicant_num = applicant_num.get_text(strip=True)
            salary = soup.find('div', class_='salary compensation__salary')
            if salary:
                salary = salary.get_text(strip=True)
            else:
                salary = soup.find('div', class_='salary compensation__salary')
            seniority_level = soup.select('span.description__job-criteria-text.description__job-criteria-text--criteria')[0].get_text(strip=True)
            employment_type = soup.select('span.description__job-criteria-text.description__job-criteria-text--criteria')[1].get_text(strip=True)
            job_function = soup.select('span.description__job-criteria-text.description__job-criteria-text--criteria')[2].get_text(strip=True)
            industries = soup.select('span.description__job-criteria-text.description__job-criteria-text--criteria')[3].get_text(strip=True)

            # Extract the required information
            job_data = {
                'job_id': job_id,
                'job_title': job_title,
                'company_name': company_name,
                'location': location,
                'post_date': post_date,
                'applicant_num': applicant_num,
                'salary': salary,
                'seniority_level': seniority_level,
                'employment_type': employment_type,
                'job_function': job_function,
                'industries': industries
            }
            
        # Store the job_data to the list for future usage
        job_list.append(job_data)
        
        # Print the extracted data to screen
        for key, value in job_data.items():
            print(f"{key}: {value}")
        print("\n---\n")
# Out:
# job_id: 3855866045
# job_title: Senior Data Scientist - Digital Identity
# company_name: Walmart
# location: San Bruno, CA
# post_date: 4 days ago
# applicant_num: 162 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Analyst, Information Technology, and Advertising
# industries: Retail, Advertising Services, and Data Infrastructure and Analytics
#
# ---
#
# job_id: 3862979601
# job_title: Data Scientist, 1+ Years of Experience
# company_name: Snap Inc.
# location: New York, United States
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3854076940
# job_title: Senior Data Scientist
# company_name: Moody's Ratings
# location: New York, NY
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3861595150
# job_title: Junior Data Scientist [Full Remote]
# company_name: Joinrs US
# location: United States
# post_date: 10 hours ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Internship
# job_function: Engineering and Information Technology
# industries: Human Resources Services
#
# ---
#
# job_id: 3850491140
# job_title: Data Scientist
# company_name: ASUS
# location: Hillsboro, OR
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Full-time
# job_function: Analyst, Strategy/Planning, and Supply Chain
# industries: Computer Hardware Manufacturing, Computers and Electronics Manufacturing, and Wholesale Computer Equipment
#
# ---
#
# job_id: 3855858013
# job_title: Data Scientist
# company_name: Vertisystem
# location: California, United States
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: $65.00/hr - $85.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Engineering
# industries: Engineering Services
#
# ---
#
# job_id: 3862429639
# job_title: Data Scientist
# company_name: Resrch Lab
# location: New York, NY
# post_date: 12 hours ago
# applicant_num: 38 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3793462569
# job_title: Data Scientist
# company_name: GovCIO
# location: Rock Island, IL
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $75,778.56/yr - $94,637.40/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3853498180
# job_title: Data Scientist
# company_name: Hyqoo
# location: New York City Metropolitan Area
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Contract
# job_function: Engineering and Consulting
# industries: Software Development and IT Services and IT Consulting
#
# ---
#
# job_id: 3852769239
# job_title: Data Scientist
# company_name: Links Technology Solutions
# location: San Jose, CA
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: $100.00/hr - $115.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting and Information Services
#
# ---
#
# job_id: 3849318319
# job_title: Data Scientist - Mental Wellbeing Analytics
# company_name: CVS Health
# location: New York, NY
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Other
# industries: Hospitals and Health Care
#
# ---
#
# job_id: 3834720854
# job_title: Data Scientist, Product
# company_name: Notion
# location: New York, NY
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: $136,000.00/yr - $160,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3849937328
# job_title: Data Scientist
# company_name: Hophr
# location: Home, KS
# post_date: 1 week ago
# applicant_num: 37 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3854764782
# job_title: Data Scientist
# company_name: OrthoNebraska
# location: Omaha, NE
# post_date: 6 days ago
# applicant_num: 26 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Hospitals and Health Care
#
# ---
#
# job_id: 3863900526
# job_title: Junior Machine Learning Engineer
# company_name: Patterned Learning Career
# location: Austin, TX
# post_date: 10 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3857557134
# job_title: Data Scientist
# company_name: Design Interactive, Inc.
# location: Florida, United States
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Analyst, Engineering, and Research
# industries: Software Development
#
# ---
#
# job_id: 3824242038
# job_title: Public Notice for Direct Hire (STEM) - Data Scientist
# company_name: WayUp
# location: El Paso, TX
# post_date: 1 month ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Other
# industries: Government Administration
#
# ---
#
# job_id: 3852719674
# job_title: Data Scientist, HEOR & RWE
# company_name: Cardio Diagnostics Holdings Inc.
# location: Chicago, IL
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Biotechnology Research
#
# ---
#
# job_id: 3859529661
# job_title: Data Scientist
# company_name: Murphy & Associates, Inc.
# location: Redmond, WA
# post_date: 1 day ago
# applicant_num: 169 applicants
# salary: $87.00/hr - $99.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Consulting, Information Technology, and Analyst
# industries: IT Services and IT Consulting, Data Infrastructure and Analytics, and Business Consulting and Services
#
# ---
#
# job_id: 3728296749
# job_title: Data Scientist
# company_name: City of New York
# location: Manhattan, NY
# post_date: 5 months ago
# applicant_num: 114 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Government Administration
#
# ---
#
# job_id: 3846350605
# job_title: Senior Data Scientist / Fully Remote / MLOps / PHD
# company_name: Motion Recruitment
# location: San Francisco, CA
# post_date: 2 weeks ago
# applicant_num: 59 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3858182172
# job_title: Data Scientist
# company_name: Zest AI
# location: United States
# post_date: 2 days ago
# applicant_num: Over 200 applicants
# salary: $95,000.00/yr - $130,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3853058784
# job_title: Data Scientist
# company_name: Charter Global
# location: San Francisco Bay Area
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Administrative, Analyst, and Science
# industries: Retail, Software Development, and Pharmaceutical Manufacturing
#
# ---
#
# job_id: 3857518902
# job_title: Data Scientist
# company_name: Brex Technologies LLC
# location: United States
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: $30.00/hr - $40.00/hr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering
# industries: Software Development
#
# ---
#
# job_id: 3849961616
# job_title: Senior Data Scientist
# company_name: OM1, Inc.
# location: Boston, MA
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Science, Research, and Analyst
# industries: Biotechnology Research and Pharmaceutical Manufacturing
#
# ---
#
# job_id: 3849103052
# job_title: Data Scientist
# company_name: TEKsystems
# location: Fort Walton Beach, FL
# post_date: 1 week ago
# applicant_num: 34 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3803992164
# job_title: Volunteer: Wildfire Prevention Financing Data Scientist- CrowdDoing Volunteer
# company_name: VolunteerMatch
# location: El Dorado Hills, CA
# post_date: 2 weeks ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Associate
# employment_type: Volunteer
# job_function: Engineering and Information Technology
# industries: Civic and Social Organizations and Non-profit Organizations
#
# ---
#
# job_id: 3850523337
# job_title: Data Scientist Sr
# company_name: PNC
# location: Pittsburgh, PA
# post_date: 1 week ago
# applicant_num: 74 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3834705716
# job_title: Data Scientist, gt.school (Remote) - $60,000/year USD
# company_name: Crossover
# location: Phoenix, AZ
# post_date: 2 days ago
# applicant_num: 54 applicants
# salary: $30.00/hr - $30.00/hr
# seniority_level: Associate
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3858582376
# job_title: Junior Data Scientist
# company_name: MHK TECH INC
# location: United States
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3855831106
# job_title: Data Scientist
# company_name: Insight Global
# location: Boston, MA
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: $140,000.00/yr - $150,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Retail Pharmacies
#
# ---
#
# job_id: 3854663368
# job_title: Data Scientist
# company_name: NeuroTech Institute
# location: Columbus, Ohio Metropolitan Area
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research Services
#
# ---
#
# job_id: 3860534046
# job_title: Marketing Data Scientist
# company_name: Collabera
# location: Bellevue, WA
# post_date: 9 hours ago
# applicant_num: 163 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Engineering and Information Technology
# industries: Information Technology & Services
#
# ---
#
# job_id: 3853578605
# job_title: AI Research Scientist
# company_name: Unreal Staffing, Inc
# location: San Francisco, CA
# post_date: 1 week ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3860806643
# job_title: Data Scientist - Product and Insights
# company_name: Avispa
# location: Newark, NJ
# post_date: 1 week ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3833821528
# job_title: Data Scientist, Growth Marketing
# company_name: iHeartMedia
# location: New York, NY
# post_date: 3 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Broadcast Media Production and Distribution
#
# ---
#
# job_id: 3853582288
# job_title: Data Scientist
# company_name: Unreal Staffing, Inc
# location: San Francisco, CA
# post_date: 1 week ago
# applicant_num: 92 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3855850785
# job_title: Junior Machine Learning Engineer
# company_name: ClearML
# location: United States
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3860178110
# job_title: Data Scientist
# company_name: CodeUp
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: 43 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3847659550
# job_title: Data Scientist II
# company_name: Honeywell
# location: Kansas City, MO
# post_date: 1 week ago
# applicant_num: 88 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Appliances, Electrical, and Electronics Manufacturing
#
# ---
#
# job_id: 3849938087
# job_title: Data Scientist
# company_name: PREDICTif Solutions
# location: Texas, United States
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3823550803
# job_title: Decision Scientist, Client Partnership Analytics
# company_name: Ibotta, Inc.
# location: Denver, CO
# post_date: 2 weeks ago
# applicant_num: 109 applicants
# salary: $80,000.00/yr - $100,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3806497192
# job_title: Principal Machine Learning Engineer
# company_name: Agero, Inc.
# location: Medford, MA
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Director
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3835755823
# job_title: Senior Data Scientist 1
# company_name: The Farmer's Dog
# location: New York, NY
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: $130,000.00/yr - $150,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Manufacturing
#
# ---
#
# job_id: 3823815300
# job_title: Business Intelligence Development Engineer (remote)
# company_name: Ford Motor Company
# location: United States
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Business Development and Sales
# industries: Motor Vehicle Manufacturing
#
# ---
#
# job_id: 3813591183
# job_title: Research Data Scientist
# company_name: Booz Allen Hamilton
# location: Washington, DC
# post_date: 1 week ago
# applicant_num: 82 applicants
# salary: $52,100.00/yr - $119,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3818888713
# job_title: Data Scientist(Remote) - Junior/Entry Level
# company_name: SynergisticIT
# location: Phoenix, AZ
# post_date: 1 month ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3856411900
# job_title: Data Scientist
# company_name: Dun & Bradstreet
# location: Florham Park, NJ
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Full-time
# job_function: Engineering, Information Technology, and Science
# industries: Information Services, IT System Data Services, and Data Infrastructure and Analytics
#
# ---
#
# job_id: 3855423628
# job_title: Data Scientist
# company_name: Insight Global
# location: San Antonio, Texas Metropolitan Area
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: $50.00/hr - $69.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3860330822
# job_title: Senior Data Scientist - Inference / Algorithms
# company_name: LinkedIn
# location: Sunnyvale, CA
# post_date: 14 hours ago
# applicant_num: 105 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering
# industries: Technology, Information and Internet and IT Services and IT Consulting
#
# ---
#
# job_id: 3860310485
# job_title: Senior Data Scientist
# company_name: The Clorox Company
# location: Durham, NC
# post_date: 10 hours ago
# applicant_num: 78 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Manufacturing
#
# ---
#
# job_id: 3863903075
# job_title: Junior Machine Learning Engineer
# company_name: Patterned Learning Career
# location: Arlington, VA
# post_date: 11 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3854761743
# job_title: Research Data Scientist
# company_name: Booz Allen Hamilton
# location: Washington, DC
# post_date: 6 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3852734486
# job_title: Data Scientist
# company_name: Microsoft
# location: Redmond, WA
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3860583055
# job_title: Data Scientist
# company_name: Seek 2 Thrive
# location: New York, NY
# post_date: 1 day ago
# applicant_num: 85 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3797405369
# job_title: Lead Data Scientist - Remote - B2B SaaS
# company_name: Jobot
# location: Boston, MA
# post_date: 3 days ago
# applicant_num: Over 200 applicants
# salary: $150,000.00/yr - $170,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3844880665
# job_title: Data Scientist - Pricing
# company_name: White Cap
# location: Norcross, GA
# post_date: 1 week ago
# applicant_num: 193 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Wholesale Building Materials
#
# ---
#
# job_id: 3860582081
# job_title: Data Scientist
# company_name: CodeUp
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: 43 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3841054855
# job_title: Data Scientist
# company_name: ChampionX Emissions Technologies
# location: Houston, TX
# post_date: 3 weeks ago
# applicant_num: 169 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Research
# industries: Oil and Gas
#
# ---
#
# job_id: 3845448733
# job_title: Data Scientist
# company_name: Deloitte
# location: Arlington, VA
# post_date: 1 week ago
# applicant_num: 97 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Management, Strategy/Planning, and Consulting
# industries: Accounting, IT Services and IT Consulting, and Business Consulting and Services
#
# ---
#
# job_id: 3851764844
# job_title: Data Scientist
# company_name: Hyqoo
# location: United States
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Contract
# job_function: Engineering and Information Technology
# industries: Broadcast Media Production and Distribution and Technology, Information and Media
#
# ---
#
# job_id: 3856352581
# job_title: Junior Data Scientist/Analyst (REMOTE)
# company_name: SynergisticIT
# location: United States
# post_date: 3 days ago
# applicant_num: 91 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3857015277
# job_title: Data Scientist
# company_name: myGwork - LGBTQ+ Business Community
# location: Austin, TX
# post_date: 3 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3860727643
# job_title: Machine Learning Engineer
# company_name: Amicus
# location: Los Angeles, CA
# post_date: 2 days ago
# applicant_num: Be among the first 25 applicants
# salary: $150,000.00/yr - $180,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3864392533
# job_title: Data Scientist-FI Solutions
# company_name: Vericast
# location: San Antonio, TX
# post_date: 9 hours ago
# applicant_num: 77 applicants
# salary: $90,000.00/yr - $110,000.00/yr
# seniority_level: Associate
# employment_type: Full-time
# job_function: Engineering
# industries: Advertising Services
#
# ---
#
# job_id: 3856017536
# job_title: Data Scientist
# company_name: USAJOBS
# location: Washington, DC
# post_date: 5 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Human Resources Services
#
# ---
#
# job_id: 3860537098
# job_title: Senior Data Scientist
# company_name: Xpanse
# location: United States
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3852308485
# job_title: Data Scientist - Product Analytics
# company_name: Observe, Inc.
# location: San Mateo, CA
# post_date: 6 days ago
# applicant_num: 93 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3855619117
# job_title: Data Scientist
# company_name: Bayforce
# location: New York City Metropolitan Area
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Information Technology and Engineering
# industries: Software Development and IT Services and IT Consulting
#
# ---
#
# job_id: 3858005565
# job_title: Data Scientist
# company_name: Visa
# location: Atlanta, GA
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3861157271
# job_title: Data Scientist
# company_name: Resrch Lab
# location: New York, NY
# post_date: 1 day ago
# applicant_num: 36 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3855742620
# job_title: Data Scientist
# company_name: TekWissen ®
# location: Bellevue, WA
# post_date: 5 days ago
# applicant_num: Over 200 applicants
# salary: $72.00/hr - $72.00/hr
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: Internet Marketplace Platforms
#
# ---
#
# job_id: 3862707722
# job_title: Data Scientist II
# company_name: Bose Corporation
# location: Framingham, MA
# post_date: 1 day ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering
# industries: Consumer Services
#
# ---
#
# job_id: 3860674298
# job_title: IT Data Scientist
# company_name: Mercedes-Benz USA
# location: Atlanta, GA
# post_date: 2 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Motor Vehicle Manufacturing
#
# ---
#
# job_id: 3862487230
# job_title: Senior Data Scientist
# company_name: Traive
# location: Boston, MA
# post_date: 5 hours ago
# applicant_num: 37 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3840471069
# job_title: Data Scientist-Customer Marketing and Personalization
# company_name: Jobs for Humanity
# location: New York, NY
# post_date: 3 weeks ago
# applicant_num: Be among the first 25 applicants
# salary: $40.00/hr - $44.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Engineering and Information Technology
# industries: Non-profit Organizations
#
# ---
#
# job_id: 3550514419
# job_title: Senior Data Scientist, E-commerce Risk/Fraud - USDS
# company_name: TikTok
# location: Seattle, WA
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $167,537.00/yr - $312,866.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Research, Information Technology, and Engineering
# industries: Entertainment Providers
#
# ---
#
# job_id: 3842698966
# job_title: Data Scientist, Autonomous Vehicle Infrastructure Analytics
# company_name: NVIDIA
# location: California, United States
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $168,000.00/yr - $287,500.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Computer Hardware Manufacturing, Software Development, and Computers and Electronics Manufacturing
#
# ---
#
# job_id: 3854754001
# job_title: Machine Learning Engineer
# company_name: Attain
# location: Redwood City, CA
# post_date: 6 days ago
# applicant_num: 88 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3859341162
# job_title: Data Scientist
# company_name: CodeUp
# location: Los Angeles, CA
# post_date: 2 days ago
# applicant_num: 47 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3858038007
# job_title: Data Scientist
# company_name: Dezign Concepts
# location: McLean, VA
# post_date: 4 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Internet Publishing
#
# ---
#
# job_id: 3859071688
# job_title: Data Scientist
# company_name: Ascendion
# location: Greater Seattle Area
# post_date: 1 day ago
# applicant_num: 154 applicants
# salary: $140,000.00/yr - $160,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Computer Games
#
# ---
#
# job_id: 3857729070
# job_title: Junior programmer/ Data scientist
# company_name: SynergisticIT
# location: Boulder, CO
# post_date: 4 days ago
# applicant_num: 73 applicants
# salary: $75,000.00/yr - $120,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Technology, Information and Media and IT Services and IT Consulting
#
# ---
#
# job_id: 3821074806
# job_title: Product Data Scientist
# company_name: Cameo
# location: Chicago, IL
# post_date: 1 month ago
# applicant_num: Over 200 applicants
# salary: $120,000.00/yr - $130,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3854928461
# job_title: Cientista de Dados - Especialista (Remoto) 27658-6888788
# company_name: Atlântico
# location: United States
# post_date: 4 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3862429541
# job_title: Data Scientist
# company_name: ArcMentors
# location: Los Angeles, CA
# post_date: 12 hours ago
# applicant_num: 34 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3864004520
# job_title: Machine Learning Engineer
# company_name: Seneca Resources
# location: Vienna, VA
# post_date: 7 hours ago
# applicant_num: 129 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3862995299
# job_title: Data Scientist - Cloud Data (New Grad)
# company_name: Lucid Motors
# location: Newark, CA
# post_date: 2 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Motor Vehicle Manufacturing
#
# ---
#
# job_id: 3862311554
# job_title: Data Scientist Entry Level
# company_name: HireMeFast LLC
# location: Tampa, FL
# post_date: 1 day ago
# applicant_num: 58 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3845407267
# job_title: Chief Data Scientist
# company_name: Robert Half
# location: Iowa City-Cedar Rapids Area
# post_date: 1 week ago
# applicant_num: 105 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Information Technology, Marketing, and Education
# industries: Education
#
# ---
#
# job_id: 3852162604
# job_title: Data Scientist Co-Op (June-Nov 2024)
# company_name: Cohere Health
# location: United States
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3863797939
# job_title: Data Scientist
# company_name: HireMeFast LLC
# location: Phoenix, AZ
# post_date: 17 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3843730636
# job_title: (USA) Senior, Data Scientist
# company_name: Walmart
# location: Hoboken, NJ
# post_date: 2 weeks ago
# applicant_num: 111 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Retail
#
# ---
#
# job_id: 3838940995
# job_title: Data Scientist
# company_name: Porch Group
# location: United States
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: $86,300.00/yr - $126,500.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3855987436
# job_title: Data Scientist
# company_name: The Lab Consulting
# location: Greater Houston
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3860581193
# job_title: Data Scientist
# company_name: Resrch Lab
# location: New York, NY
# post_date: 1 day ago
# applicant_num: 76 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3812497068
# job_title: Data Scientist
# company_name: TikTok
# location: San Jose, CA
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: $144,000.00/yr - $312,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Information Technology, Product Management, and Engineering
# industries: Entertainment Providers
#
# ---
#
# job_id: 3864304562
# job_title: Junior Machine Learning Engineer
# company_name: Team Remotely Inc
# location: Grand Rapids, MI
# post_date: 9 hours ago
# applicant_num: 28 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3855475486
# job_title: Data Scientist (Skunkworks) - REMOTE
# company_name: StreetLight
# location: Seattle, WA
# post_date: 4 days ago
# applicant_num: Be among the first 25 applicants
# salary: $135,000.00/yr - $155,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3855877385
# job_title: Data Scientist
# company_name: Polly
# location: United States
# post_date: 4 days ago
# applicant_num: 97 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3862309759
# job_title: Junior Data Scientist
# company_name: Team Remotely Inc
# location: Indianapolis, IN
# post_date: 1 day ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3809359030
# job_title: Data Scientist / Senior Data Scientist, Analytics
# company_name: DoorDash
# location: Los Angeles, CA
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $133,000.00/yr - $243,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3770788509
# job_title: Data Scientist
# company_name: DigiFlight, Inc.
# location: Fort Meade, MD
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3840556999
# job_title: Data Scientist - Mid
# company_name: Cherokee Federal
# location: Maryland, United States
# post_date: 2 weeks ago
# applicant_num: 48 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3838582588
# job_title: Senior Data Scientist
# company_name: WTW
# location: Fort Lee, NJ
# post_date: 2 weeks ago
# applicant_num: 150 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3826179330
# job_title: Data Scientist (L5) - Systems Test Enablement
# company_name: Netflix
# location: Los Gatos, CA
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $150,000.00/yr - $750,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Entertainment Providers, Technology, Information and Internet, and Movies, Videos, and Sound
#
# ---
#
# job_id: 3863171764
# job_title: Jr Data Scientist- US/Canada only
# company_name: Dexian Inc
# location: California, PA
# post_date: 22 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Nanotechnology Research
#
# ---
#
# job_id: 3846912572
# job_title: DATA SCIENTIST
# company_name: City of New York
# location: Manhattan, NY
# post_date: 2 weeks ago
# applicant_num: 88 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Government Administration
#
# ---
#
# job_id: 3858975629
# job_title: Data Scientist
# company_name: Tech Advisory Panel
# location: New York, NY
# post_date: 2 days ago
# applicant_num: 117 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3836228565
# job_title: Data Scientist
# company_name: Koniag Government Services
# location: Washington, DC
# post_date: 4 days ago
# applicant_num: 57 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3850727249
# job_title: Data Scientist
# company_name: Ataraxis AI
# location: New York, NY
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: $75,000.00/yr - $140,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Biotechnology
#
# ---
#
# job_id: 3856677804
# job_title: Machine Learning Engineer
# company_name: Steneral Consulting
# location: United States
# post_date: 4 days ago
# applicant_num: 31 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3855831463
# job_title: Junior Data Scientist
# company_name: ClearML
# location: United States
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3826161080
# job_title: Lead Data Scientist
# company_name: Harnham
# location: United States
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: $130,000.00/yr - $140,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Analyst, Engineering, and Consulting
# industries: Financial Services, Banking, and Real Estate
#
# ---
#
# job_id: 3811928150
# job_title: Principal Data Scientist
# company_name: Unisys
# location: United States
# post_date: 1 week ago
# applicant_num: 190 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3799833599
# job_title: Sr Data Scientist - Experimentation
# company_name: Chewy
# location: Boston, MA
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Retail
#
# ---
#
# job_id: 3864768534
# job_title: Junior Data Scientist
# company_name: ClearML
# location: United States
# post_date: 35 minutes ago
# applicant_num: 31 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3859907533
# job_title: Entry Level Data Scientist
# company_name: SynergisticIT
# location: New York, NY
# post_date: 19 hours ago
# applicant_num: 27 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3858583560
# job_title: Jr Data Scientist
# company_name: Tech Consulting
# location: Atlanta, GA
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: $32.00/yr - $36.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Science, Research, and Information Technology
# industries: IT Services and IT Consulting, Software Development, and Research Services
#
# ---
#
# job_id: 3795288355
# job_title: Data Scientist, Ecommerce - USDS
# company_name: TikTok
# location: Mountain View, CA
# post_date: 2 weeks ago
# applicant_num: 159 applicants
# salary: $144,000.00/yr - $240,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Research, Analyst, and Information Technology
# industries: Entertainment Providers
#
# ---
#
# job_id: 3860986099
# job_title: Senior Research Scientist, Machine Learning
# company_name: Clarifai
# location: Washington, DC
# post_date: 1 day ago
# applicant_num: 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Other
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3862530931
# job_title: Data Scientist - Remote
# company_name: OneDigital
# location: United States
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3862424755
# job_title: Data Scientist
# company_name: ArcMentors
# location: Los Angeles, CA
# post_date: 12 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3848843128
# job_title: 24-50 Hydrometeorology Data Scientist (Data Scientist I)
# company_name: Texas Water Development Board
# location: Austin, Texas Metropolitan Area
# post_date: 1 week ago
# applicant_num: 60 applicants
# salary: $7,349.25/mo - $8,583.33/mo
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Science, Analyst, and Design
# industries: Government Administration, Climate Data and Analytics, and Software Development
#
# ---
#
# job_id: 3860720773
# job_title: Machine Learning Engineer
# company_name: Continua AI, Inc.
# location: Seattle, WA
# post_date: 2 days ago
# applicant_num: 85 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3859971989
# job_title: Data Scientist
# company_name: STARK BANK
# location: New York, NY
# post_date: 19 hours ago
# applicant_num: 90 applicants
# salary: $110,000.00/yr - $175,000.00/yr
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Banking
#
# ---
#
# job_id: 3863507651
# job_title: Data Scientist
# company_name: ArcMentors
# location: Los Angeles, CA
# post_date: 2 hours ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3775808817
# job_title: Senior Clinical Data Scientist
# company_name: ConcertAI
# location: San Francisco Bay Area
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Research, Analyst, and Information Technology
# industries: Biotechnology Research
#
# ---
#
# job_id: 3863901202
# job_title: Junior Data Scientist
# company_name: Team Remotely Inc
# location: Raleigh, NC
# post_date: 15 hours ago
# applicant_num: 85 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3856515261
# job_title: Data Scientist
# company_name: Visa
# location: Foster City, CA
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3841312991
# job_title: Data Scientist
# company_name: Globant
# location: Dallas, TX
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $60.00/hr - $65.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Business Development and Sales
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3818360598
# job_title: Entry Level Data Scientist
# company_name: SynergisticIT
# location: Houston, TX
# post_date: 1 month ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3843569261
# job_title: Data Scientist/Data Engineer
# company_name: Caesars Entertainment, Inc.
# location: Las Vegas, NV
# post_date: 2 weeks ago
# applicant_num: 29 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Hospitality
#
# ---
#
# job_id: 3848956475
# job_title: Data Scientist 1
# company_name: Elder Research
# location: Arlington, VA
# post_date: 1 week ago
# applicant_num: 47 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3860728512
# job_title: Machine Learning Engineer
# company_name: Amicus
# location: New York, NY
# post_date: 2 days ago
# applicant_num: 28 applicants
# salary: $150,000.00/yr - $180,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3860377483
# job_title: Junior Data Scientist
# company_name: Ryan Consulting Group, LLC
# location: Charlotte Metro
# post_date: 11 hours ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Analyst and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3815506367
# job_title: Data Scientist (83563BR)
# company_name: Yale University
# location: New Haven, CT
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Higher Education
#
# ---
#
# job_id: 3839221537
# job_title: Data Visualization Jr. (006-24)
# company_name: Anglicotech, LLC
# location: Arlington, VA
# post_date: 3 weeks ago
# applicant_num: 186 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Analyst
# industries: Data Infrastructure and Analytics
#
# ---
#
# job_id: 3862453692
# job_title: Data Scientist
# company_name: Alkymi
# location: United States
# post_date: 11 hours ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Associate
# employment_type: Full-time
# job_function: Information Technology and Engineering
# industries: Software Development, IT Services and IT Consulting, and Financial Services
#
# ---
#
# job_id: 3731943010
# job_title: Senior Data Scientist
# company_name: Yext
# location: New York, NY
# post_date: 2 weeks ago
# applicant_num: Over 200 applicants
# salary: $177,300.00/yr - $295,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development and Technology, Information and Internet
#
# ---
#
# job_id: 3854625234
# job_title: Data Scientist
# company_name: University of Kentucky
# location: Frankfort, KY
# post_date: 1 week ago
# applicant_num: 163 applicants
# salary: $51,491.00/yr - $84,950.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Research, Science, and Analyst
# industries: Higher Education and Research Services
#
# ---
#
# job_id: 3838500680
# job_title: Data Reviewer - Entry Level - NOT Data Scientist
# company_name: Eurofins BioPharma Product Testing (US)
# ...
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Retail
#
# ---
#
# job_id: 3689595905
# job_title: Staff Data Scientist
# company_name: SentiLink
# location: United States
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: $200,000.00/yr - $235,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3860395204
# job_title: Data Scientist
# company_name: AllSTEM Connections
# location: Columbus, OH
# post_date: 6 hours ago
# applicant_num: 87 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3809059353
# job_title: Data Scientists Modeling
# company_name: ICONMA
# location: Dearborn, MI
# post_date: 1 month ago
# applicant_num: 73 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Engineering and Information Technology
# industries: Staffing and Recruiting
#
# ---
#
# job_id: 3787781079
# job_title: Expression of Interest: Senior Data Scientist
# company_name: Fingerprint for Success (F4S)
# location: San Diego, CA
# post_date: 3 months ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Executive
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Internet Publishing
#
# ---
#
# job_id: 3860920502
# job_title: Data Scientist
# company_name: Aquent Talent
# location: Seattle, WA
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: $80.00/hr - $86.00/hr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Computer Games
#
# ---
#
# job_id: 3860348387
# job_title: Data Scientist
# company_name: BorrowWorks
# location: Fort Worth, TX
# post_date: 7 hours ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3830712796
# job_title: Senior Data Scientist, Corporate Functions (Risk, Legal, and Compliance)
# company_name: Prudential Financial
# location: Newark, NJ
# post_date: 1 week ago
# applicant_num: 86 applicants
# salary: $99,000.00/yr - $163,200.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3860729279
# job_title: Machine Learning Engineer
# company_name: Amicus
# location: Austin, TX
# post_date: 2 days ago
# applicant_num: 25 applicants
# salary: $150,000.00/yr - $180,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3833697042
# job_title: Data Scientist
# company_name: Nicoll Curtin
# location: New York City Metropolitan Area
# post_date: 4 weeks ago
# applicant_num: Over 200 applicants
# salary: $250,000.00/yr - $350,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Technology, Information and Media, IT Services and IT Consulting, and Space Research and Technology
#
# ---
#
# job_id: 3855374077
# job_title: Data Scientist
# company_name: Graphite GTC
# location: Philadelphia, PA
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3839308504
# job_title: Data Reviewer - Entry Level - *NOT Data Scientist*
# company_name: Eurofins
# location: Columbia, MO
# post_date: 3 weeks ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Administrative
# industries: Biotechnology Research
#
# ---
#
# job_id: 3860579414
# job_title: Data Scientist
# company_name: ArcMentors
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: 35 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3853245738
# job_title: Machine Learning Engineer
# company_name: Oscar
# location: New York, NY
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: $160,000.00/yr - $200,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Consumer Services
#
# ---
#
# job_id: 3853535578
# job_title: Data Scientist I (Clinical)
# company_name: Pyramid Consulting, Inc
# location: Waltham, MA
# post_date: 1 week ago
# applicant_num: 111 applicants
# salary: $50.00/hr - $55.00/hr
# seniority_level: Not Applicable
# employment_type: Contract
# job_function: Information Technology
# industries: Hospitals and Health Care and Pharmaceutical Manufacturing
#
# ---
#
# job_id: 3862333694
# job_title: Data Scientist - NYC
# company_name: AdTheorent
# location: New York, NY
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Advertising Services
#
# ---
#
# job_id: 3853418923
# job_title: Data Scientist with python
# company_name: Diverse Lynx
# location: Irving, TX
# post_date: 6 days ago
# applicant_num: 37 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Contract
# job_function: Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3862933364
# job_title: Python Engineer (ML & AI)
# company_name: Avenue Code
# location: United States
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Not Applicable
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3801549468
# job_title: Principal Data Scientist - BCG X & BCG Fed
# company_name: BCG X
# location: Atlanta, GA
# post_date: 3 weeks ago
# applicant_num: 84 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3847800270
# job_title: Senior Data Scientist Manager
# company_name: Google
# location: New York, NY
# post_date: 1 week ago
# applicant_num: 75 applicants
# salary: $216,000.00/yr - $317,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Finance, Analyst, and Accounting/Auditing
# industries: Information Services and Technology, Information and Internet
#
# ---
#
# job_id: 3848958584
# job_title: Data Scientist
# company_name: Harvey Nash
# location: United States
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: $66.00/hr - $76.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Other and Information Technology
# industries: Software Development, Information Services, and IT Services and IT Consulting
#
# ---
#
# job_id: 3858224052
# job_title: Data Scientist
# company_name: Resrch Lab
# location: New York, NY
# post_date: 3 days ago
# applicant_num: 71 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3860724108
# job_title: Data Scientist | Analytics
# company_name: Machinify, Inc.
# location: Palo Alto, CA
# post_date: 2 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3858767405
# job_title: Data Scientist
# company_name: Catalyst Technical Consulting Group, LLC
# location: Fort Meade, MD
# post_date: 4 days ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Internet Publishing
#
# ---
#
# job_id: 3857251816
# job_title: Data Scientist
# company_name: Rent The Runway
# location: Brooklyn, NY
# post_date: 4 days ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Supply Chain, Information Technology, and Engineering
# industries: Advertising Services, Technology, Information and Internet, and Retail
#
# ---
#
# job_id: 3815602771
# job_title: Senior Data Scientist
# company_name: Constellation
# location: New York, NY
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: $140,000.00/yr - $170,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Advertising Services, Marketing Services, and Technology, Information and Internet
#
# ---
#
# job_id: 3851331090
# job_title: Data Scientist
# company_name: ClosedLoop
# location: Austin, TX
# post_date: 1 week ago
# applicant_num: 189 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3862929712
# job_title: Data Scientist II
# company_name: Oscar Health
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: 192 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Insurance
#
# ---
#
# job_id: 3853292868
# job_title: Data Scientist
# company_name: Propel, Inc
# location: Brooklyn, NY
# post_date: 1 week ago
# applicant_num: 105 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3858979161
# job_title: Data Scientist
# company_name: Seek 2 Thrive
# location: New York, NY
# post_date: 2 days ago
# applicant_num: 151 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Part-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3860331856
# job_title: Data Scientist I
# company_name: GM Financial
# location: Fort Worth, TX
# post_date: 8 hours ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3862957300
# job_title: Data Scientist
# company_name: Retool
# location: San Francisco, CA
# post_date: 7 hours ago
# applicant_num: 96 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---
#
# job_id: 3827225365
# job_title: Staff Data Scientist
# company_name: Walmart
# location: Bentonville, AR
# post_date: 1 week ago
# applicant_num: 81 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Retail
#
# ---
#
# job_id: 3860733028
# job_title: Machine Learning Engineer
# company_name: Amicus
# location: San Jose, CA
# post_date: 2 days ago
# applicant_num: 32 applicants
# salary: $150,000.00/yr - $180,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Technology, Information and Internet
#
# ---
#
# job_id: 3829298077
# job_title: Data Scientist
# company_name: EDO, Inc.
# location: New York City Metropolitan Area
# post_date: 1 week ago
# applicant_num: Over 200 applicants
# salary: $110,000.00/yr - $150,000.00/yr
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering and Analyst
# industries: Advertising Services and Technology, Information and Media
#
# ---
#
# job_id: 3862586176
# job_title: Data Scientist - Entry level
# company_name: SynergisticIT
# location: San Francisco, CA
# post_date: 1 day ago
# applicant_num: 26 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Biotechnology Research and IT Services and IT Consulting
#
# ---
#
# job_id: 3690878374
# job_title: Data Scientist, Proprietary Research
# company_name: Point72
# location: New York, United States
# post_date: 3 weeks ago
# applicant_num: Over 200 applicants
# salary: $125,000.00/yr - $150,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3854233511
# job_title: Data Scientist
# company_name: Henderson Scott
# location: United States
# post_date: 6 days ago
# applicant_num: Over 200 applicants
# salary: $200,000.00/yr - $200,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Information Technology
# industries: Hospitals and Health Care
#
# ---
#
# job_id: 3860177195
# job_title: Data Scientist
# company_name: ArcMentors
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Research
#
# ---
#
# job_id: 3862944404
# job_title: Data Scientist III
# company_name: orangepeople
# location: California, United States
# post_date: 1 day ago
# applicant_num: 193 applicants
# salary: $60.00/hr - $67.00/hr
# seniority_level: Mid-Senior level
# employment_type: Contract
# job_function: Information Technology
# industries: Social Networking Platforms
#
# ---
#
# job_id: 3836559409
# job_title: Principal Data Scientist
# company_name: Educational Media Foundation K-LOVE & Air1 Media Networks
# location: Franklin, TN
# post_date: 3 weeks ago
# applicant_num: Be among the first 25 applicants
# salary: None
# seniority_level: Director
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Broadcast Media Production and Distribution
#
# ---
#
# job_id: 3858176868
# job_title: Machine Learning Engineer
# company_name: Zest AI
# location: United States
# post_date: 2 days ago
# applicant_num: Over 200 applicants
# salary: $95,000.00/yr - $130,000.00/yr
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Financial Services
#
# ---
#
# job_id: 3853186297
# job_title: Data Scientist
# company_name: Tredence Inc.
# location: Ankeny, IA
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Engineering
# industries: Retail
#
# ---
#
# job_id: 3853177514
# job_title: Data Scientists
# company_name: Big Data Federation, Inc.
# location: San Jose, CA
# post_date: 1 week ago
# applicant_num: 100 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Information Services
#
# ---
#
# job_id: 3853999823
# job_title: Data scientist
# company_name: Ayesa
# location: Northeastern United States
# post_date: 6 days ago
# applicant_num: 181 applicants
# salary: None
# seniority_level: Mid-Senior level
# employment_type: Full-time
# job_function: Information Technology
# industries: Business Consulting and Services
#
# ---
#
# job_id: 3862386383
# job_title: Lead Data Scientist
# company_name: PSEG
# location: Hicksville, NY
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Director
# employment_type: Full-time
# job_function: Other and Research
# industries: Utilities
#
# ---
#
# job_id: 3840493024
# job_title: Data Scientist
# company_name: Tata Consultancy Services
# location: St Louis, MO
# post_date: 2 weeks ago
# applicant_num: 78 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: IT Services and IT Consulting
#
# ---
#
# job_id: 3862981508
# job_title: Data Scientist, 1+ Years of Experience
# company_name: Snap Inc.
# location: Los Angeles, CA
# post_date: 1 day ago
# applicant_num: Over 200 applicants
# salary: None
# seniority_level: Entry level
# employment_type: Full-time
# job_function: Engineering and Information Technology
# industries: Software Development
#
# ---

# %%
len(job_list)
# Out:
# 265

# %% [markdown]
# As mentioned earlier, the number of listings decreased to 265.
# We will store these in the 'LinkedIn' database for further analysis on the popularity.

# %% [markdown]
# ---

# %% [markdown]
# ### __Part 3 - Save the extracted data to MySQL database__
# Lastly, we import the extracted data into a MySQL database.
# We use 'job_id' as the primary key because it is a unique identifier.

# %%
# Ignore warnings
warnings.filterwarnings("ignore")
SQL_DB = "LinkedIn"

def create_sql_table(SQL_TABLE_CONTRIBUTOR, SQL_TABLE_CONTRIBUTOR_DEF):
    try:
        # Connect to server
        conn = mysql.connector.connect(host = 'localhost',
                                       user = 'root',
                                       password = 'E6j8xs8q.')
        cursor = conn.cursor()
        
        query = "CREATE DATABASE IF NOT EXISTS " + SQL_DB
        print(query)
        cursor.execute(query);
        
        query = "CREATE TABLE IF NOT EXISTS " + SQL_DB + "." + SQL_TABLE_CONTRIBUTOR + " " + SQL_TABLE_CONTRIBUTOR_DEF + ";";
        print(query)
        cursor.execute(query);
        cursor.close()
        conn.close()
        return

    except IOError as e:
        print(e)

# %%
SQL_TABLE_CONTRIBUTOR = "data_scientist"
SQL_TABLE_CONTRIBUTOR_DEF = "(" + \
        "job_id VARCHAR(100) NOT NULL PRIMARY KEY" + \
        ",job_title VARCHAR(100)" + \
        ",company_name VARCHAR(100)" + \
        ",location VARCHAR(100)" + \
        ",post_date VARCHAR(50)" + \
        ",applicant_num VARCHAR(100)" + \
        ",salary VARCHAR(200)" + \
        ",seniority_level VARCHAR(100)" + \
        ",employment_type VARCHAR(50)" + \
        ",job_function VARCHAR(200)" + \
        ",industries VARCHAR(200)" + \
        ")"
# Use the function to create database 
create_sql_table(SQL_TABLE_CONTRIBUTOR, SQL_TABLE_CONTRIBUTOR_DEF)
# Out:
# CREATE DATABASE IF NOT EXISTS LinkedIn
# CREATE TABLE IF NOT EXISTS LinkedIn.data_scientist (job_id VARCHAR(100) NOT NULL PRIMARY KEY,job_title VARCHAR(100),company_name VARCHAR(100),location VARCHAR(100),post_date VARCHAR(50),applicant_num VARCHAR(100),salary VARCHAR(200),seniority_level VARCHAR(100),employment_type VARCHAR(50),job_function VARCHAR(200),industries VARCHAR(200));

# %%
try:
    # Connect to server
    conn = mysql.connector.connect(host = 'localhost',
                                   database = 'LinkedIn',
                                   user = 'root',
                                   password = 'E6j8xs8q.')

    cursor = conn.cursor()
    
    # Parameterized statement to match the table schema
    parameterized_stmt = ("INSERT INTO " + SQL_TABLE_CONTRIBUTOR +
                          " (job_id, job_title, company_name, location,"
                          "post_date, applicant_num, salary, seniority_level, "
                          "employment_type, job_function, industries) "
                          "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);")

    for data in job_list:
        # Explicitly specify the order of columns to match the INSERT statement
        values = tuple(data[column] for column in ['job_id', 'job_title', 'company_name', 'location', 'post_date',
                                                    'applicant_num', 'salary', 'seniority_level', 'employment_type',
                                                    'job_function', 'industries'])
        # Execute the insert statement with the values
        cursor.execute(parameterized_stmt, values)

        # Print the job_id of the inserted data
        print('Inserted:', data['job_id'])
    
    conn.commit()
    cursor.close()
    conn.close()
    
except IOError as e:
    print(e)
# Out:
# Inserted: 3855866045
# Inserted: 3862979601
# Inserted: 3854076940
# Inserted: 3861595150
# Inserted: 3850491140
# Inserted: 3855858013
# Inserted: 3862429639
# Inserted: 3793462569
# Inserted: 3853498180
# Inserted: 3852769239
# Inserted: 3849318319
# Inserted: 3834720854
# Inserted: 3849937328
# Inserted: 3854764782
# Inserted: 3863900526
# Inserted: 3857557134
# Inserted: 3824242038
# Inserted: 3852719674
# Inserted: 3859529661
# Inserted: 3728296749
# Inserted: 3846350605
# Inserted: 3858182172
# Inserted: 3853058784
# Inserted: 3857518902
# Inserted: 3849961616
# Inserted: 3849103052
# Inserted: 3803992164
# Inserted: 3850523337
# Inserted: 3834705716
# Inserted: 3858582376
# Inserted: 3855831106
# Inserted: 3854663368
# Inserted: 3860534046
# Inserted: 3853578605
# Inserted: 3860806643
# Inserted: 3833821528
# Inserted: 3853582288
# Inserted: 3855850785
# Inserted: 3860178110
# Inserted: 3847659550
# Inserted: 3849938087
# Inserted: 3823550803
# Inserted: 3806497192
# Inserted: 3835755823
# Inserted: 3823815300
# Inserted: 3813591183
# Inserted: 3818888713
# Inserted: 3856411900
# Inserted: 3855423628
# Inserted: 3860330822
# Inserted: 3860310485
# Inserted: 3863903075
# Inserted: 3854761743
# Inserted: 3852734486
# Inserted: 3860583055
# Inserted: 3797405369
# Inserted: 3844880665
# Inserted: 3860582081
# Inserted: 3841054855
# Inserted: 3845448733
# Inserted: 3851764844
# Inserted: 3856352581
# Inserted: 3857015277
# Inserted: 3860727643
# Inserted: 3864392533
# Inserted: 3856017536
# Inserted: 3860537098
# Inserted: 3852308485
# Inserted: 3855619117
# Inserted: 3858005565
# Inserted: 3861157271
# Inserted: 3855742620
# Inserted: 3862707722
# Inserted: 3860674298
# Inserted: 3862487230
# Inserted: 3840471069
# Inserted: 3550514419
# Inserted: 3842698966
# Inserted: 3854754001
# Inserted: 3859341162
# Inserted: 3858038007
# Inserted: 3859071688
# Inserted: 3857729070
# Inserted: 3821074806
# Inserted: 3854928461
# Inserted: 3862429541
# Inserted: 3864004520
# Inserted: 3862995299
# Inserted: 3862311554
# Inserted: 3845407267
# Inserted: 3852162604
# Inserted: 3863797939
# Inserted: 3843730636
# Inserted: 3838940995
# Inserted: 3855987436
# Inserted: 3860581193
# Inserted: 3812497068
# Inserted: 3864304562
# Inserted: 3855475486
# Inserted: 3855877385
# Inserted: 3862309759
# Inserted: 3809359030
# Inserted: 3770788509
# Inserted: 3840556999
# Inserted: 3838582588
# Inserted: 3826179330
# Inserted: 3863171764
# Inserted: 3846912572
# Inserted: 3858975629
# Inserted: 3836228565
# Inserted: 3850727249
# Inserted: 3856677804
# Inserted: 3855831463
# Inserted: 3826161080
# Inserted: 3811928150
# Inserted: 3799833599
# Inserted: 3864768534
# Inserted: 3859907533
# Inserted: 3858583560
# Inserted: 3795288355
# Inserted: 3860986099
# Inserted: 3862530931
# Inserted: 3862424755
# Inserted: 3848843128
# Inserted: 3860720773
# Inserted: 3859971989
# Inserted: 3863507651
# Inserted: 3775808817
# Inserted: 3863901202
# Inserted: 3856515261
# Inserted: 3841312991
# Inserted: 3818360598
# Inserted: 3843569261
# Inserted: 3848956475
# Inserted: 3860728512
# Inserted: 3860377483
# Inserted: 3815506367
# Inserted: 3839221537
# Inserted: 3862453692
# Inserted: 3731943010
# Inserted: 3854625234
# Inserted: 3838500680
# Inserted: 3860722872
# Inserted: 3859422058
# Inserted: 3855478281
# Inserted: 3848276079
# Inserted: 3859083103
# Inserted: 3821673769
# Inserted: 3835924984
# Inserted: 3847701531
# Inserted: 3862794631
# Inserted: 3860718959
# Inserted: 3853417151
# Inserted: 3859043348
# Inserted: 3799311624
# Inserted: 3860728511
# Inserted: 3862312442
# Inserted: 3855477400
# Inserted: 3860722307
# Inserted: 3860990379
# Inserted: 3851773982
# Inserted: 3853581291
# Inserted: 3813594035
# Inserted: 3844441857
# Inserted: 3854748128
# Inserted: 3847884587
# Inserted: 3774932117
# Inserted: 3859408313
# Inserted: 3857211517
# Inserted: 3857765862
# Inserted: 3845099939
# Inserted: 3848284933
# Inserted: 3756077272
# Inserted: 3861696805
# Inserted: 3829888187
# Inserted: 3857350143
# Inserted: 3793241145
# Inserted: 3863472256
# Inserted: 3848283848
# Inserted: 3840444847
# Inserted: 3842801581
# Inserted: 3863111235
# Inserted: 3859996915
# Inserted: 3859338760
# Inserted: 3862940904
# Inserted: 3858021032
# Inserted: 3862414733
# Inserted: 3815776955
# Inserted: 3863900554
# Inserted: 3805750638
# Inserted: 3860932447
# Inserted: 3854362334
# Inserted: 3844402901
# Inserted: 3837348471
# Inserted: 3854419201
# Inserted: 3860174658
# Inserted: 3860726934
# Inserted: 3846690311
# Inserted: 3824829348
# Inserted: 3860971043
# Inserted: 3863903076
# Inserted: 3854416628
# Inserted: 3860718894
# Inserted: 3858976610
# Inserted: 3855418633
# Inserted: 3862308771
# Inserted: 3831043502
# Inserted: 3861154624
# Inserted: 3861498785
# Inserted: 3854481081
# Inserted: 3860312233
# Inserted: 3860733029
# Inserted: 3859093324
# Inserted: 3831573986
# Inserted: 3857262592
# Inserted: 3860723838
# Inserted: 3843341563
# Inserted: 3853735090
# Inserted: 3689595905
# Inserted: 3860395204
# Inserted: 3809059353
# Inserted: 3787781079
# Inserted: 3860920502
# Inserted: 3860348387
# Inserted: 3830712796
# Inserted: 3860729279
# Inserted: 3833697042
# Inserted: 3855374077
# Inserted: 3839308504
# Inserted: 3860579414
# Inserted: 3853245738
# Inserted: 3853535578
# Inserted: 3862333694
# Inserted: 3853418923
# Inserted: 3862933364
# Inserted: 3801549468
# Inserted: 3847800270
# Inserted: 3848958584
# Inserted: 3858224052
# Inserted: 3860724108
# Inserted: 3858767405
# Inserted: 3857251816
# Inserted: 3815602771
# Inserted: 3851331090
# Inserted: 3862929712
# Inserted: 3853292868
# Inserted: 3858979161
# Inserted: 3860331856
# Inserted: 3862957300
# Inserted: 3827225365
# Inserted: 3860733028
# Inserted: 3829298077
# Inserted: 3862586176
# Inserted: 3690878374
# Inserted: 3854233511
# Inserted: 3860177195
# Inserted: 3862944404
# Inserted: 3836559409
# Inserted: 3858176868
# Inserted: 3853186297
# Inserted: 3853177514
# Inserted: 3853999823
# Inserted: 3862386383
# Inserted: 3840493024
# Inserted: 3862981508
